# %%
import numpy as np
import pandas as pd
from Linear_Regression import LinearRegression

df = pd.read_csv("housing.csv")
df = df.drop(columns=["ocean_proximity"])
df = df.dropna()
df.shape
# Out:
# (20433, 9)

# %%
y = df['median_house_value'].values
x = df.drop(columns=['median_house_value']).values

# %%
model = LinearRegression(x, y)
model.fit()

# %%
model.beta
# Out:
# array([[-3.58539575e+06],
#        [-4.27301205e+04],
#        [-4.25097369e+04],
#        [ 1.15790031e+03],
#        [-8.24972507e+00],
#        [ 1.13820707e+02],
#        [-3.83855780e+01],
#        [ 4.77013513e+01],
#        [ 4.02975217e+04]])

# %%
model.variance()
# Out:
# np.float64(4840189708.743852)

# %%
model.standard_deviation()
# Out:
# np.float64(69571.47194607752)

# %%
model.rmse()
# Out:
# np.float64(69556.14839566675)
